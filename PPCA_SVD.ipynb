# %% [markdown]
# ## Use PPCA / SVD to eliminate co-variant / orthogonal features

# %%
#imports
import pandas as pd
import sklearn
from sklearn.decomposition import PCA
from collections import Counter
import numpy as np
from numpy import shape, isnan, nanmean, average, log, cov
from numpy.matlib import repmat
from numpy.random import normal
from numpy.linalg import inv, det, eig
from numpy import identity as eye
from numpy import trace as tr
from scipy.linalg import orth
name = "pyppca" #import for PPCA
from pyppca import ppca

# %%
# read in a given CSV file and prepare for TrainTestSplit
df = pd.read_csv("./preprocessed_data/2016-19ChronAbsenteeism.csv", sep=",")
X = df.drop(["Unnamed: 0"], axis=1)
#Y = df['dropout_rate']?
X.shape
# Out:
# (6471, 29)

# %%
# date columns need to be converted to int for each dataset
X['AcademicYear'] = X['AcademicYear'].replace(['2016-17', '2017-18','2018-19'], ['1','2','3'])

X
# Out:
#      AcademicYear AggregateLevel  CountryCode  DistrictCode  SchoolCode  \
# 0               1              S           32       10322.0    100057.0
# 1               2              S           32       10322.0    100057.0
# 2               3              S           32       10322.0    100057.0
# 3               1              S            1       61259.0    100065.0
# 4               2              S            1       61259.0    100065.0
# ...           ...            ...          ...           ...         ...
# 6466            2              S           30       66464.0   6120356.0
# 6467            3              S           30       66464.0   6120356.0
# 6468            1              S            5       10058.0   9010745.0
# 6469            2              S            5       10058.0   9010745.0
# 6470            3              S            5       10058.0   9010745.0
#
#      CountyName                          DistrictName  \
# 0        Plumas     Plumas County Office of Education
# 1        Plumas     Plumas County Office of Education
# 2        Plumas     Plumas County Office of Education
# 3       Alameda                       Oakland Unified
# 4       Alameda                       Oakland Unified
# ...         ...                                   ...
# 6466     Orange                    Capistrano Unified
# 6467     Orange                    Capistrano Unified
# 6468  Calaveras  Calaveras County Office of Education
# 6469  Calaveras  Calaveras County Office of Education
# 6470  Calaveras  Calaveras County Office of Education
#
#                                    SchoolName CharterYN  CAR_RB  ...  CAR_GF  \
# 0                     Plumas County Community       All     NaN  ...     NaN
# 1                     Plumas County Community       All     NaN  ...     NaN
# 2                     Plumas County Community       All     NaN  ...     NaN
# 3                          Oakland Unity High       All    19.0  ...    16.9
# 4                          Oakland Unity High       All    31.3  ...    16.6
# ...                                       ...       ...     ...  ...     ...
# 6466  Opportunities for Learning - Capistrano       All     NaN  ...    10.1
# 6467  Opportunities for Learning - Capistrano       All     0.0  ...     0.8
# 6468                      Oakendell Community       All     NaN  ...     NaN
# 6469                      Oakendell Community       All     NaN  ...     NaN
# 6470                      Oakendell Community       All     NaN  ...     NaN
#
#       CAR_GX  CAR_GZ  CAR_SE  CAR_SD  CAR_SS  CAR_SM  CAR_SF  CAR_SH  CAR_TA
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN    90.0
# 3        NaN     NaN    24.1     7.4    15.0     NaN     NaN     NaN    14.7
# 4        NaN     NaN    16.7     8.3    15.0     NaN     NaN     NaN    14.5
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 6466     NaN     NaN     NaN    18.5    11.7     NaN     NaN     NaN     7.3
# 6467     NaN     NaN     0.0     2.6     5.0     NaN     NaN     NaN     3.3
# 6468     NaN     NaN     NaN     0.0     4.5     NaN     5.0     NaN     4.5
# 6469     NaN     NaN     NaN     7.7     0.0     NaN     0.0     NaN     5.0
# 6470     NaN     NaN     NaN     0.0     4.5     NaN     4.5     NaN     4.5
#
# [6471 rows x 29 columns]

# %%
#we need to store SchoolName, CountyName before we drop
#we need to initialize this dictionary before running the function
keyz = []
SchoolName_valz = []
DistrictName_valz = []
stringInfo = {}

def get_string_info(df):
    ''' Creates a dictionary with a given schoolcode as the key and an array as the values.
        The contained values are the associated school name and dictrict name, respectively.
        We need to keep this ledger since PCA / SVD require integer-only values. Lastly, we need
        to drop the created string rows.
        Note: should we add County names to this dict?'''
    for col in df['SchoolCode']:
        keyz.append(col)
    for column in df['SchoolName']:
        SchoolName_valz.append(column)
    for col in df['DistrictName']:
        DistrictName_valz.append(column)
    for i, name in enumerate(keyz):
        stringInfo[name] = [SchoolName_valz[i], DistrictName_valz[i]]
    return stringInfo

# %%
names_dict = get_string_info(X)
names_dict
# Out:
# {100057.0: ['Plumas County Community', 'Oakendell Community'],
#  100065.0: ['Oakland Unity High', 'Oakendell Community'],
#  100081.0: ['William J. (Pete) Knight High', 'Oakendell Community'],
#  100180.0: ['Mountain Oaks High', 'Oakendell Community'],
#  100198.0: ['Golden Valley High', 'Oakendell Community'],
#  100255.0: ['Desert Mirage High', 'Oakendell Community'],
#  100305.0: ['Cypress Charter High', 'Oakendell Community'],
#  100354.0: ['Hawthorne Math and Science Academy', 'Oakendell Community'],
#  100420.0: ['Vista Murrieta High', 'Oakendell Community'],
#  100529.0: ['Cesar E. Chavez High', 'Oakendell Community'],
#  100602.0: ['Lennox Mathematics, Science and Technology Academy',
#   'Oakendell Community'],
#  100677.0: ['High Tech LA', 'Oakendell Community'],
#  100701.0: ['MetWest High', 'Oakendell Community'],
#  100750.0: ['Wallis Annenberg High', 'Oakendell Community'],
#  100800.0: ['Central City Value', 'Oakendell Community'],
#  101162.0: ['Pioneer High', 'Oakendell Community'],
#  101196.0: ['ICEF View Park Preparatory High', 'Oakendell Community'],
#  101329.0: ['William J. Johnston Community Day', 'Oakendell Community'],
#  101410.0: ['Oak View High School & Education Center', 'Oakendell Community'],
#  101477.0: ['Leadership Public Schools: Richmond', 'Oakendell Community'],
#  101576.0: ['Weston Ranch High', 'Oakendell Community'],
#  101659.0: ['CATCH Prep Charter High, Inc.', 'Oakendell Community'],
#  101675.0: ['Oscar De La Hoya Animo Charter High', 'Oakendell Community'],
#  101725.0: ['Grizzly ChalleNGe Charter', 'Oakendell Community'],
#  101741.0: ['Select Community Day (Secondary)', 'Oakendell Community'],
#  101774.0: ["Five Keys Charter (SF Sheriff's)", 'Oakendell Community'],
#  101832.0: ['Futures High', 'Oakendell Community'],
#  101881.0: ['New Technology High', 'Oakendell Community'],
#  101899.0: ['George Washington Carver School of Arts and Science',
#   'Oakendell Community'],
#  101907.0: ['The MET', 'Oakendell Community'],
#  101956.0: ['Aspire Benjamin Holt College Preparatory Academy',
#   'Oakendell Community'],
#  101972.0: ['Rosemont High', 'Oakendell Community'],
#  101980.0: ['Farragut Academy', 'Oakendell Community'],
#  102012.0: ['Dixon Community Day', 'Oakendell Community'],
#  102038.0: ['Sacramento Charter High', 'Oakendell Community'],
#  102103.0: ['Jordan (June) School for Equity', 'Oakendell Community'],
#  102137.0: ['Aggeler Community Day', 'Oakendell Community'],
#  102178.0: ['Future Bound Independent Study Secondary', 'Oakendell Community'],
#  102186.0: ['Ronald Reagan Academy', 'Oakendell Community'],
#  102236.0: ['Inderkum High', 'Oakendell Community'],
#  102285.0: ['Pioneer Valley High', 'Oakendell Community'],
#  102293.0: ['Foresthill High', 'Oakendell Community'],
#  102368.0: ['Ann Sobrato High', 'Oakendell Community'],
#  102392.0: ['Millennium Charter', 'Oakendell Community'],
#  102434.0: ['Animo South Los Angeles Charter', 'Oakendell Community'],
#  102459.0: ['Golden Valley High', 'Oakendell Community'],
#  102475.0: ['West Ranch High', 'Oakendell Community'],
#  102764.0: ['Richard A. Alonzo Community Day', 'Oakendell Community'],
#  102830.0: ['Wilmer Amina Carter High', 'Oakendell Community'],
#  102871.0: ['Arnold O. Beckman High', 'Oakendell Community'],
#  102913.0: ['Middle College High', 'Oakendell Community'],
#  102921.0: ['Dr. Richard A. Vladovic Harbor Teacher Preparation Academy',
#   'Oakendell Community'],
#  105726.0: ['Mission Hills High', 'Oakendell Community'],
#  105734.0: ['Great Oak High', 'Oakendell Community'],
#  105858.0: ['Pajaro Valley High', 'Oakendell Community'],
#  105916.0: ['Monterey Trail High', 'Oakendell Community'],
#  106047.0: ['Blue Ridge', 'Oakendell Community'],
#  106112.0: ['Pinnacles High', 'Oakendell Community'],
#  106120.0: ['SIATech', 'Oakendell Community'],
#  106153.0: ['Eel River Community', 'Oakendell Community'],
#  106161.0: ['Eureka Community', 'Oakendell Community'],
#  106179.0: ['Southern Humboldt Community', 'Oakendell Community'],
#  106195.0: ['Humboldt County Office of Education Court',
#   'Oakendell Community'],
#  106203.0: ['Humboldt County Office of Education Juvenile Hall Court',
#   'Oakendell Community'],
#  106229.0: ['Palmiter Special Education', 'Oakendell Community'],
#  106237.0: ['Elinor Lincoln Hickey Jr./Sr. High', 'Oakendell Community'],
#  106245.0: ['North Area Community', 'Oakendell Community'],
#  106278.0: ['El Centro Jr./Sr. High', 'Oakendell Community'],
#  106328.0: ['Canyon Crest Academy', 'Oakendell Community'],
#  106344.0: ['Northwest Prep Charter', 'Oakendell Community'],
#  106377.0: ['Global Youth Charter', 'Oakendell Community'],
#  106401.0: ['Alameda Science and Technology Institute', 'Oakendell Community'],
#  106435.0: ['Camino Nuevo Charter High', 'Oakendell Community'],
#  106542.0: ['Community Day High', 'Oakendell Community'],
#  106567.0: ['Nova Academy Early College High', 'Oakendell Community'],
#  106625.0: ['Elk Creek', 'Oakendell Community'],
#  106666.0: ['Bar-O', 'Oakendell Community'],
#  106716.0: ['Hamilton High', 'Oakendell Community'],
#  106732.0: ['High Tech High International', 'Oakendell Community'],
#  106831.0: ['Animo Venice Charter High', 'Oakendell Community'],
#  106849.0: ['Animo Pat Brown', 'Oakendell Community'],
#  106997.0: ['Orthopaedic Hospital', 'Oakendell Community'],
#  107003.0: ['Northridge Academy High', 'Oakendell Community'],
#  107029.0: ['San Diego International Studies', 'Oakendell Community'],
#  107052.0: ['San Diego Business/Leadership', 'Oakendell Community'],
#  107078.0: ['Kearny Digital Media & Design', 'Oakendell Community'],
#  107086.0: ['Kearny SCT', 'Oakendell Community'],
#  107094.0: ['Kearny College Connections', 'Oakendell Community'],
#  107102.0: ['Kearny Eng Innov & Design', 'Oakendell Community'],
#  107110.0: ['Six Rivers Charter High', 'Oakendell Community'],
#  107136.0: ['Whitmore Charter High', 'Oakendell Community'],
#  107151.0: ['Escuela Popular/Center for Training and Careers, Family Learning',
#   'Oakendell Community'],
#  107177.0: ['Crawford High', 'Oakendell Community'],
#  107219.0: ['San Diego Science and Technology', 'Oakendell Community'],
#  107300.0: ['City Arts and Tech High', 'Oakendell Community'],
#  107326.0: ['Far East County Programs', 'Oakendell Community'],
#  107383.0: ['River Delta Community Day', 'Oakendell Community'],
#  107482.0: ['San Diego Metro Career and Tech', 'Oakendell Community'],
#  107516.0: ['Summit Leadership Academy-High Desert', 'Oakendell Community'],
#  107524.0: ['Acalanes Center for Independent Study', 'Oakendell Community'],
#  107649.0: ['Countryside Community Day', 'Oakendell Community'],
#  107672.0: ['Sequoia High', 'Oakendell Community'],
#  107706.0: ['Blue Heron', 'Oakendell Community'],
#  107722.0: ['River Valley High', 'Oakendell Community'],
#  107755.0: ['Port of Los Angeles High', 'Oakendell Community'],
#  107797.0: ['Heritage High', 'Oakendell Community'],
#  107920.0: ['Lakeside High', 'Oakendell Community'],
#  108076.0: ['Central Valley High', 'Oakendell Community'],
#  108084.0: ['Whitney High', 'Oakendell Community'],
#  108092.0: ['Orange Cove High', 'Oakendell Community'],
#  108159.0: ['Cesar Chavez High', 'Oakendell Community'],
#  108191.0: ['Summit High', 'Oakendell Community'],
#  108225.0: ['Ronald E. McNair High', 'Oakendell Community'],
#  108365.0: ['Segerstrom High', 'Oakendell Community'],
#  108407.0: ['Eastside High', 'Oakendell Community'],
#  108555.0: ['Design Science Middle College High', 'Oakendell Community'],
#  108670.0: ['Leadership Public Schools - Hayward', 'Oakendell Community'],
#  108688.0: ['Academy of the Redwoods', 'Oakendell Community'],
#  108753.0: ['Pleasant Grove High', 'Oakendell Community'],
#  108787.0: ['High Tech High Media Arts', 'Oakendell Community'],
#  108811.0: ['Abraxis Charter', 'Oakendell Community'],
#  108878.0: ['CHAMPS - Charter HS of Arts-Multimedia & Performing',
#   'Oakendell Community'],
#  108894.0: ['Alliance Judy Ivie Burton Technology Academy High',
#   'Oakendell Community'],
#  108936.0: ['Alliance Collins Family College-Ready High',
#   'Oakendell Community'],
#  108944.0: ['Lighthouse Community Charter High', 'Oakendell Community'],
#  108951.0: ['Arthur A. Benjamin Health Professions High',
#   'Oakendell Community'],
#  108977.0: ['Fowler Academy Community Day (9-12)', 'Oakendell Community'],
#  108993.0: ['Easton Community Day', 'Oakendell Community'],
#  109108.0: ['Citrus Hill High', 'Oakendell Community'],
#  109447.0: ['Santee Education Complex', 'Oakendell Community'],
#  109454.0: ['South East High', 'Oakendell Community'],
#  109462.0: ['Maywood Academy High', 'Oakendell Community'],
#  109512.0: ['Cal Burke High', 'Oakendell Community'],
#  109538.0: ['Marco Antonio Firebaugh High', 'Oakendell Community'],
#  109652.0: ['Val Verde Student Success Academy', 'Oakendell Community'],
#  109751.0: ['Visalia Charter Independent Study', 'Oakendell Community'],
#  109900.0: ['Vista Real Charter High', 'Oakendell Community'],
#  109942.0: ['Los Angeles International Charter High', 'Oakendell Community'],
#  109991.0: ['Crescent View West Public Charter', 'Oakendell Community'],
#  110064.0: ['University Preparatory', 'Oakendell Community'],
#  110106.0: ['Orange Grove High', 'Oakendell Community'],
#  110189.0: ['McClymonds High', 'Oakendell Community'],
#  110205.0: ['Lemoore Middle College High', 'Oakendell Community'],
#  110270.0: ['Clovis Community Day Secondary', 'Oakendell Community'],
#  110288.0: ['Lewis Opportunity', 'Oakendell Community'],
#  110320.0: ['Gene Drevno Community Day', 'Oakendell Community'],
#  110395.0: ['Lincoln Community Day', 'Oakendell Community'],
#  110403.0: ['Valley Teen Ranch Community Day', 'Oakendell Community'],
#  110460.0: ['Core Learning Academy at Conley-Caraballo High',
#   'Oakendell Community'],
#  110478.0: ['Alternative Learning Academy at Conley-Caraballo High',
#   'Oakendell Community'],
#  110494.0: ['Bidwell Continuation High', 'Oakendell Community'],
#  110593.0: ['James C. Enochs High', 'Oakendell Community'],
#  110627.0: ['Eleanor Roosevelt High', 'Oakendell Community'],
#  110668.0: ['Frida Kahlo High', 'Oakendell Community'],
#  110759.0: ['John F. Kennedy High', 'Oakendell Community'],
#  110965.0: ['Madera South High', 'Oakendell Community'],
#  110999.0: ['Frontier High', 'Oakendell Community'],
#  111070.0: ['Rowland Assistive Technology Academy', 'Oakendell Community'],
#  111195.0: ['Classical Academy High', 'Oakendell Community'],
#  111435.0: ['Marina High', 'Oakendell Community'],
#  111443.0: ['Centennial Independent Study', 'Oakendell Community'],
#  111484.0: ['New Village Girls Academy', 'Oakendell Community'],
#  111492.0: ['Alliance Patti And Peter Neuwirth Leadership Academy',
#   'Oakendell Community'],
#  111500.0: ['Alliance Dr. Olga Mohan High', 'Oakendell Community'],
#  111575.0: ['Animo Ralph Bunche Charter High', 'Oakendell Community'],
#  111583.0: ['Animo Jackie Robinson High', 'Oakendell Community'],
#  111625.0: ['Animo Watts College Preparatory Academy', 'Oakendell Community'],
#  111658.0: ['Alliance Marc & Eva Stern Math and Science',
#   'Oakendell Community'],
#  111666.0: ['Early College High', 'Oakendell Community'],
#  111799.0: ['East Bay Arts High', 'Oakendell Community'],
#  111831.0: ['Olympian High', 'Oakendell Community'],
#  111856.0: ['American Indian Public High', 'Oakendell Community'],
#  111872.0: ['SOAR High (Students On Academic Rise)', 'Oakendell Community'],
#  112029.0: ['School of Business and Tourism at Contreras Learning Complex',
#   'Oakendell Community'],
#  112037.0: ['East Valley Senior High', 'Oakendell Community'],
#  112045.0: ['Arleta High', 'Oakendell Community'],
#  112052.0: ['Panorama High', 'Oakendell Community'],
#  112359.0: ['Sequoia School', 'Oakendell Community'],
#  112367.0: ['William & Marian Ghidotti High', 'Oakendell Community'],
#  112425.0: ['Natomas Pacific Pathways Prep', 'Oakendell Community'],
#  112508.0: ['Bright Star Secondary Charter Academy', 'Oakendell Community'],
#  112565.0: ['New Vision High', 'Oakendell Community'],
#  112573.0: ['Adelante High', 'Oakendell Community'],
#  112722.0: ['Summit Preparatory Charter High', 'Oakendell Community'],
#  112870.0: ['Contreras Learning Center-Los Angeles School of Global Studies',
#   'Oakendell Community'],
#  112896.0: ['Monterey Peninsula Unified School District Community Day',
#   'Oakendell Community'],
#  113118.0: ['Dougherty Valley High', 'Oakendell Community'],
#  113159.0: ['Tahquitz High', 'Oakendell Community'],
#  113183.0: ['Marin County Juvenile Court', 'Oakendell Community'],
#  113191.0: ['Heritage High', 'Oakendell Community'],
#  113266.0: ['Camp Glenwood', 'Oakendell Community'],
#  113274.0: ['Thomas E. Mathews Community', 'Oakendell Community'],
#  113332.0: ['Gateway Center', 'Oakendell Community'],
#  113381.0: ['San Juan Hills High', 'Oakendell Community'],
#  113431.0: ['University Preparatory Academy Charter', 'Oakendell Community'],
#  113555.0: ['Clovis North High', 'Oakendell Community'],
#  113571.0: ['Vista del Lago High', 'Oakendell Community'],
#  113787.0: ['Cesar Chavez Community', 'Oakendell Community'],
#  113902.0: ['Impact Academy of Arts & Technology', 'Oakendell Community'],
#  114025.0: ['Lincoln High', 'Oakendell Community'],
#  114132.0: ['Shasta Plus', 'Oakendell Community'],
#  114140.0: ['George and Evelyn Stein Continuation', 'Oakendell Community'],
#  114157.0: ['Patriot High', 'Oakendell Community'],
#  114207.0: ['Feather River Academy', 'Oakendell Community'],
#  114215.0: ['Lakeport Community Day', 'Oakendell Community'],
#  114231.0: ['Foothill Plus', 'Oakendell Community'],
#  114249.0: ['Enterprise Plus', 'Oakendell Community'],
#  114264.0: ['North County Trade Tech High', 'Oakendell Community'],
#  114272.0: ['SAVA - Sacramento Academic and Vocational Academy',
#   'Oakendell Community'],
#  114314.0: ['Bitney Prep High', 'Oakendell Community'],
#  114389.0: ['Mirus Secondary', 'Oakendell Community'],
#  114397.0: ['Opportunities For Learning - Baldwin Park II',
#   'Oakendell Community'],
#  114421.0: ['KIPP King Collegiate High', 'Oakendell Community'],
#  114439.0: ['Mission View Public', 'Oakendell Community'],
#  114462.0: ['Health Sciences High', 'Oakendell Community'],
#  114496.0: ['Dr. TJ Owens Gilroy Early College Academy',
#   'Oakendell Community'],
#  114504.0: ['Summit High (Continuation)', 'Oakendell Community'],
#  114512.0: ['California City High', 'Oakendell Community'],
#  114520.0: ['Arroyo Paseo Charter High', 'Oakendell Community'],
#  114538.0: ['Shattuck Independent Study', 'Oakendell Community'],
#  114546.0: ['School of Engineering & Sciences', 'Oakendell Community'],
#  114553.0: ['University High', 'Oakendell Community'],
#  114678.0: ['High Tech High Chula Vista', 'Oakendell Community'],
#  114694.0: ['High Tech High North County', 'Oakendell Community'],
#  114736.0: ['Hector G. Godinez', 'Oakendell Community'],
#  114751.0: ['Pathway Community Day', 'Oakendell Community'],
#  114769.0: ['OUSD Community Day', 'Oakendell Community'],
#  114777.0: ['Pathway Independent Study', 'Oakendell Community'],
#  114850.0: ['West Adams Preparatory High', 'Oakendell Community'],
#  114868.0: ['Oakland Charter High', 'Oakendell Community'],
#  115238.0: ['ARISE High', 'Oakendell Community'],
#  115253.0: ['Discovery Charter Preparatory School #2', 'Oakendell Community'],
#  115329.0: ['West Sacramento Early College Prep Charter',
#   'Oakendell Community'],
#  115337.0: ['Los Angeles County Online High', 'Oakendell Community'],
#  115386.0: ['Civicorps Corpsmember Academy', 'Oakendell Community'],
#  115402.0: ['Edward C. Merlo Institute of Environmental Studies',
#   'Oakendell Community'],
#  115444.0: ['Canyon Ridge High', 'Oakendell Community'],
#  115451.0: ['Major General Raymond Murray High', 'Oakendell Community'],
#  115527.0: ['Campbell High Community Day', 'Oakendell Community'],
#  115667.0: ['Oakland International High', 'Oakendell Community'],
#  115709.0: ['Riverside Virtual', 'Oakendell Community'],
#  115873.0: ['East Hills Academy', 'Oakendell Community'],
#  115998.0: ['San Pasqual Academy', 'Oakendell Community'],
#  116046.0: ['Irvine Adult Transition Programs', 'Oakendell Community'],
#  116285.0: ['Redondo Beach Learning Academy', 'Oakendell Community'],
#  116368.0: ['Mission Oak High', 'Oakendell Community'],
#  116376.0: ['Lathrop High', 'Oakendell Community'],
#  116384.0: ['Robert F. Kennedy High', 'Oakendell Community'],
#  116392.0: ['Independence High', 'Oakendell Community'],
#  116400.0: ['Mira Monte High', 'Oakendell Community'],
#  116459.0: ['Antelope High', 'Oakendell Community'],
#  116509.0: ['Alliance Morgan McKinzie High', 'Oakendell Community'],
#  116590.0: ['Harmony Magnet Academy', 'Oakendell Community'],
#  116640.0: ['Dunlap Leadership Academy', 'Oakendell Community'],
#  116681.0: ['Earle Jamieson Educational Options', 'Oakendell Community'],
#  116707.0: ['Encore Jr./Sr. High School for the Performing and Visual Arts',
#   'Oakendell Community'],
#  116723.0: ['Academy of Careers and Exploration', 'Oakendell Community'],
#  116848.0: ['Valley Community Day', 'Oakendell Community'],
#  116889.0: ['KIPP San Jose Collegiate', 'Oakendell Community'],
#  116897.0: ['Cosumnes Oaks High', 'Oakendell Community'],
#  116913.0: ['Sugarloaf Mountain, Juvenile Hall Program',
#   'Oakendell Community'],
#  116954.0: ['Jack London Community Day', 'Oakendell Community'],
#  117010.0: ['Minarets High', 'Oakendell Community'],
#  117051.0: ['Edward R. Roybal Learning Center', 'Oakendell Community'],
#  117069.0: ['Helen Bernstein High', 'Oakendell Community'],
#  117077.0: ['APEX Academy', 'Oakendell Community'],
#  117143.0: ['Canyon Oaks Youth Center', 'Oakendell Community'],
#  117218.0: ['Dozier-Libbey Medical High', 'Oakendell Community'],
#  117598.0: ['Alliance Piera Barbaglia Shaheen Health Services Academy',
#   'Oakendell Community'],
#  117606.0: ['Alliance Leichtman-Levine Family Foundation Environmental Science High',
#   'Oakendell Community'],
#  117622.0: ['Magnolia Science Academy 4', 'Oakendell Community'],
#  117689.0: ['Sentinel High', 'Oakendell Community'],
#  117721.0: ['Contreras Learning Center-Academic Leadership Community',
#   'Oakendell Community'],
#  117747.0: ['Los Angeles High School of the Arts', 'Oakendell Community'],
#  117762.0: ['School for the Visual Arts and Humanities',
#   'Oakendell Community'],
#  117911.0: ['New Millennium Secondary', 'Oakendell Community'],
#  117994.0: ['YouthBuild Charter School of California', 'Oakendell Community'],
#  118018.0: ['Clovis Online Charter', 'Oakendell Community'],
#  118075.0: ['Learning Works', 'Oakendell Community'],
#  118109.0: ['Silver Valley Community Day', 'Oakendell Community'],
#  118133.0: ["Five Keys Adult School (SF Sheriff's)", 'Oakendell Community'],
#  118141.0: ["Five Keys Independence HS (SF Sheriff's)", 'Oakendell Community'],
#  118307.0: ['Pride Continuation', 'Oakendell Community'],
#  118315.0: ['East Village High', 'Oakendell Community'],
#  118380.0: ['Christopher High', 'Oakendell Community'],
#  118430.0: ['Mission Vista High', 'Oakendell Community'],
#  118521.0: ['Centinela Valley Independent Study', 'Oakendell Community'],
#  118588.0: ['Alain Leroy Locke College Preparatory Academy',
#   'Oakendell Community'],
#  118653.0: ['Ralph J. Bunche High', 'Oakendell Community'],
#  118745.0: ['Gerber Jr./Sr. High', 'Oakendell Community'],
#  118794.0: ['Murrieta Mesa High', 'Oakendell Community'],
#  118802.0: ['Citrus Valley High', 'Oakendell Community'],
#  118851.0: ['King-Chavez Community High', 'Oakendell Community'],
#  118885.0: ['Shadow Hills High', 'Oakendell Community'],
#  118919.0: ['Sierra Pacific High', 'Oakendell Community'],
#  118935.0: ['Del Norte High', 'Oakendell Community'],
#  118950.0: ['Sherman Thomas Charter High', 'Oakendell Community'],
#  118968.0: ['Community Day', 'Oakendell Community'],
#  119016.0: ['Da Vinci Science', 'Oakendell Community'],
#  119040.0: ['John C. Kimball High', 'Oakendell Community'],
#  119073.0: ['Crossroads Alternative Education Center', 'Oakendell Community'],
#  119081.0: ['Bishop Independent Study', 'Oakendell Community'],
#  119115.0: ['Oak Hills High', 'Oakendell Community'],
#  119131.0: ['Liberty Ranch High', 'Oakendell Community'],
#  119354.0: ['Independence High', 'Oakendell Community'],
#  119404.0: ['Yorba Linda High', 'Oakendell Community'],
#  119487.0: ['Western Sierra Collegiate Academy', 'Oakendell Community'],
#  119503.0: ['Everest Public High', 'Oakendell Community'],
#  119578.0: ['Da Vinci Charter Academy', 'Oakendell Community'],
#  119602.0: ['University Preparatory High', 'Oakendell Community'],
#  119636.0: ['Da Vinci Design', 'Oakendell Community'],
#  119651.0: ['Sun Valley High', 'Oakendell Community'],
#  119727.0: ['Ramon C. Cortines School of Visual and Performing Arts',
#   'Oakendell Community'],
#  119743.0: ['Stockton Early College Academy', 'Oakendell Community'],
#  119784.0: ['Stockton High', 'Oakendell Community'],
#  119859.0: ['Gateway to College at Laney College', 'Oakendell Community'],
#  119875.0: ['S.F. International High', 'Oakendell Community'],
#  119958.0: ['Academy (The)- SF @McAteer', 'Oakendell Community'],
#  119966.0: ['Felicitas and Gonzalo Mendez High', 'Oakendell Community'],
#  119990.0: ['Diego Hills Charter', 'Oakendell Community'],
#  120246.0: ['Fowler Academy Independent Study', 'Oakendell Community'],
#  120360.0: ['Daniel Pearl Journalism & Communications Magnet',
#   'Oakendell Community'],
#  120394.0: ['Inspire School of Arts and Sciences', 'Oakendell Community'],
#  120402.0: ['Alta Vista Alternative High', 'Oakendell Community'],
#  120410.0: ['iHigh Virtual Academy', 'Oakendell Community'],
#  120444.0: ['Mt. McKinley', 'Oakendell Community'],
#  120535.0: ['Crescent View South Charter', 'Oakendell Community'],
#  120568.0: ['Options for Youth-San Bernardino', 'Oakendell Community'],
#  120584.0: ['Pivot Online Charter - North Bay', 'Oakendell Community'],
#  120634.0: ['Architecture, Construction & Engineering Charter High (ACE)',
#   'Oakendell Community'],
#  120659.0: ['Visalia Technical Early College', 'Oakendell Community'],
#  120758.0: ['Jurupa Hills High', 'Oakendell Community'],
#  120808.0: ['Dorothy V. Johnson Community Day', 'Oakendell Community'],
#  120923.0: ['Pacheco High', 'Oakendell Community'],
#  120931.0: ['Livermore Valley Charter Preparatory High',
#   'Oakendell Community'],
#  120964.0: ['Phoenix Secondary', 'Oakendell Community'],
#  121087.0: ['American Canyon High', 'Oakendell Community'],
#  121129.0: ['Joseph A. Gregori High', 'Oakendell Community'],
#  121228.0: ['Young Adult Program', 'Oakendell Community'],
#  121285.0: ['Alliance Cindy and Bill Simon Technology Academy High',
#   'Oakendell Community'],
#  121293.0: ['Alliance Tennenbaum Family Technology High',
#   'Oakendell Community'],
#  121426.0: ['IvyTech Charter', 'Oakendell Community'],
#  121673.0: ['NOVA Academy - Coachella', 'Oakendell Community'],
#  121723.0: ['San Joaquin Building Futures Academy', 'Oakendell Community'],
#  121731.0: ['Albert Einstein Academy for Letters, Arts and Sciences',
#   'Oakendell Community'],
#  121822.0: ['Nidorf, Barry J.', 'Oakendell Community'],
#  121871.0: ['Los Padrinos Juvenile Hall', 'Oakendell Community'],
#  121897.0: ['Central Juvenile Hall', 'Oakendell Community'],
#  121905.0: ['Kirby, Dorothy Camp', 'Oakendell Community'],
#  121921.0: ['Afflerbaugh-Paige Camp', 'Oakendell Community'],
#  121939.0: ['Rockey, Glenn Camp', 'Oakendell Community'],
#  121954.0: ['Road to Success Academy at Campus Kilpatrick',
#   'Oakendell Community'],
#  121970.0: ['Gonzales, David Camp', 'Oakendell Community'],
#  121988.0: ['Scott, Joseph Camp', 'Oakendell Community'],
#  121996.0: ['Scudder, Kenyon Camp', 'Oakendell Community'],
#  122010.0: ['Mendenhall, William Camp', 'Oakendell Community'],
#  122028.0: ['Onizuka Camp', 'Oakendell Community'],
#  122036.0: ['McNair Camp', 'Oakendell Community'],
#  122044.0: ['Jarvis Camp', 'Oakendell Community'],
#  122051.0: ['Scobee Camp', 'Oakendell Community'],
#  122077.0: ['Smith Camp', 'Oakendell Community'],
#  122275.0: ['Environmental and Social Policy Magnet', 'Oakendell Community'],
#  122333.0: ['Math, Science, & Technology Magnet Academy at Roosevelt High',
#   'Oakendell Community'],
#  122341.0: ['Esteban Torres East LA Performing Arts Magnet',
#   'Oakendell Community'],
#  122358.0: ['Humanitas Academy of Art and Technology at Esteban E. Torres High No. 4',
#   'Oakendell Community'],
#  122366.0: ['Social Justice Leadership Academy at Esteban E. Torres High No. 5',
#   'Oakendell Community'],
#  122374.0: ['East Los Angeles Renaissance Academy at Esteban E. Torres High No. 2',
#   'Oakendell Community'],
#  122382.0: ['Engineering and Technology Academy at Esteban E. Torres High No. 3',
#   'Oakendell Community'],
#  122432.0: ['Edgewood High', 'Oakendell Community'],
#  122473.0: ['Elm High', 'Oakendell Community'],
#  122606.0: ['PUC Lakeview Charter High', 'Oakendell Community'],
#  122697.0: ['REALM Charter High', 'Oakendell Community'],
#  122705.0: ['Burton Horizon Academy', 'Oakendell Community'],
#  122788.0: ['School for Entrepreneurship and Technology',
#   'Oakendell Community'],
#  122820.0: ['Mission Community Day', 'Oakendell Community'],
#  122879.0: ['Walter J. Katnich Community Day', 'Oakendell Community'],
#  123133.0: ['Alliance Susan and Eric Smidt Technology High',
#   'Oakendell Community'],
#  123141.0: ['Alliance Ted K. Tajima High', 'Oakendell Community'],
#  123273.0: ['Crescent Valley Public Charter', 'Oakendell Community'],
#  123331.0: ["Division of Unaccompanied Children's Services (DUCS)",
#   'Oakendell Community'],
#  123414.0: ['Mountain Vista Educational Center', 'Oakendell Community'],
#  123570.0: ['Wheatland Community Day High', 'Oakendell Community'],
#  123604.0: ['Phoenix Academy Residential Education Center',
#   'Oakendell Community'],
#  123612.0: ['Pacific Lodge Residential Education Center',
#   'Oakendell Community'],
#  123620.0: ['Mountain Vista High', 'Oakendell Community'],
#  123745.0: ['Summit Public School: Rainier', 'Oakendell Community'],
#  123786.0: ['Credo High', 'Oakendell Community'],
#  123794.0: ['Summit Public School: Tahoma', 'Oakendell Community'],
#  123802.0: ['Health Careers Academy', 'Oakendell Community'],
#  123950.0: ['Firebaugh Community Day', 'Oakendell Community'],
#  124131.0: ['California Preparatory Academy', 'Oakendell Community'],
#  124248.0: ['Pacific Law Academy', 'Oakendell Community'],
#  124271.0: ['Diego Valley Charter', 'Oakendell Community'],
#  124362.0: ['Valley Academy of Arts and Sciences', 'Oakendell Community'],
#  124370.0: ['Cesar E. Chavez Learning Academies-Arts/Theatre/Entertain Mag',
#   'Oakendell Community'],
#  124388.0: ['Cesar E. Chavez Learning Academies-Social Justice Humanitas Academy',
#   'Oakendell Community'],
#  124396.0: ['Cesar E. Chavez Learning Academies-Academy of Scientific Exploration (ASE)',
#   'Oakendell Community'],
#  124404.0: ['Cesar E. Chavez Learning Academies-Technology Preparatory Academy',
#   'Oakendell Community'],
#  124420.0: ['School of History and Dramatic Arts at Sonia Sotomayor Learning Academies',
#   'Oakendell Community'],
#  124479.0: ['Dr. Maya Angelou Community High', 'Oakendell Community'],
#  124487.0: ['Public Service Community at Diego Rivera Learning Complex',
#   'Oakendell Community'],
#  124495.0: ['Communication and Technology at Diego Rivera Learning Complex',
#   'Oakendell Community'],
#  124503.0: ['Diego Rivera Learning Complex Green Design STEAM Academy',
#   'Oakendell Community'],
#  124511.0: ['Performing Arts Community at Diego Rivera Learning Complex',
#   'Oakendell Community'],
#  124552.0: ['Applied Technology Center', 'Oakendell Community'],
#  124560.0: ['Synergy Quantum Academy', 'Oakendell Community'],
#  124610.0: ['El Puente', 'Oakendell Community'],
#  124628.0: ['BUSD School of Opportunity', 'Oakendell Community'],
#  124669.0: ['eCademy Charter at Crane', 'Oakendell Community'],
#  124727.0: ['Kingsburg Independent Study High', 'Oakendell Community'],
#  124750.0: ['Heritage Valley Independent Study', 'Oakendell Community'],
#  124776.0: ['Loma Vista Charter', 'Oakendell Community'],
#  124834.0: ['Sierra Academy of Expeditionary Learning', 'Oakendell Community'],
#  124883.0: ['Animo College Preparatory Academy', 'Oakendell Community'],
#  124891.0: ['Alliance Renee and Meyer Luskin Academy High',
#   'Oakendell Community'],
#  124933.0: ['PUC Early College Academy for Leaders and Scholars (ECALS)',
#   'Oakendell Community'],
#  124941.0: ['Alliance Margaret M. Bloomfield Technology Academy High',
#   'Oakendell Community'],
#  124982.0: ['Ambassador Phillip V. Sanchez Public Charter',
#   'Oakendell Community'],
#  124990.0: ['Urban Corps of San Diego County Charter', 'Oakendell Community'],
#  125021.0: ['Minarets Charter High', 'Oakendell Community'],
#  125047.0: ['Community Day School III', 'Oakendell Community'],
#  125062.0: ['Tierra Del Sol Continuation High', 'Oakendell Community'],
#  125153.0: ['Beach High-Intensive Learning Program', 'Oakendell Community'],
#  125161.0: ['Castlemont High', 'Oakendell Community'],
#  125237.0: ['Riverside County Education Academy', 'Oakendell Community'],
#  125328.0: ['Central Coast New Tech High', 'Oakendell Community'],
#  125351.0: ['Palm Canyon', 'Oakendell Community'],
#  125401.0: ['Insight @ San Diego', 'Oakendell Community'],
#  125419.0: ['Adelanto High', 'Oakendell Community'],
#  125427.0: ['Calero High', 'Oakendell Community'],
#  125443.0: ['Santa Clara Community Day', 'Oakendell Community'],
#  125450.0: ['Indian Springs High', 'Oakendell Community'],
#  125500.0: ['Grand Terrace High School at the Ray Abril Jr. Educational Complex',
#   'Oakendell Community'],
#  125617.0: ['ACE Charter High', 'Oakendell Community'],
#  125633.0: ['California Heritage Youthbuild Academy II',
#   'Oakendell Community'],
#  125674.0: ['Condor High', 'Oakendell Community'],
#  125716.0: ['Fremont High', 'Oakendell Community'],
#  125732.0: ['Hillcrest High', 'Oakendell Community'],
#  125765.0: ['Millennium Charter High', 'Oakendell Community'],
#  125864.0: ['Ednovate - USC Hybrid High College Prep', 'Oakendell Community'],
#  125989.0: ['STEM Academy at Bernstein High', 'Oakendell Community'],
#  126003.0: ['Academies of the Antelope Valley', 'Oakendell Community'],
#  126037.0: ['Samueli Academy', 'Oakendell Community'],
#  126094.0: ['be.tech', 'Oakendell Community'],
#  126136.0: ['Math and Science College Preparatory', 'Oakendell Community'],
#  126185.0: ['Academy of Science and Engineering', 'Oakendell Community'],
#  126243.0: ['Chaffey District Online High', 'Oakendell Community'],
#  126292.0: ['Reedley Middle College High', 'Oakendell Community'],
#  126300.0: ['Vista Visions Academy', 'Oakendell Community'],
#  126474.0: ['Hilda L. Solis Learning Academy School of Technology, Business and Education',
#   'Oakendell Community'],
#  126482.0: ['Augustus F. Hawkins High A Critical Design and Gaming',
#   'Oakendell Community'],
#  126490.0: ['Augustus F. Hawkins High B Community Health Advocates',
#   'Oakendell Community'],
#  126508.0: ['Augustus F. Hawkins High C Responsible Indigenous Social Entrepreneurship',
#   'Oakendell Community'],
#  126516.0: ['Linda Esperanza Marquez High A Huntington Park Institute of Applied Medicine',
#   'Oakendell Community'],
#  126524.0: ['Linda Esperanza Marquez High B LIBRA Academy',
#   'Oakendell Community'],
#  126532.0: ['Linda Esperanza Marquez High C School of Social Justice',
#   'Oakendell Community'],
#  126540.0: ['Science, Technology, Engineering, Arts and Mathematics at Legacy High School Complex',
#   'Oakendell Community'],
#  126557.0: ['Visual and Performing Arts at Legacy High School Complex',
#   'Oakendell Community'],
#  126573.0: ['Academy for Multilingual Arts and Science at Mervyn M. Dymally High',
#   'Oakendell Community'],
#  126615.0: ['Academies of Education and Empowerment at Carson High',
#   'Oakendell Community'],
#  126623.0: ['Academy of Medical Arts at Carson High', 'Oakendell Community'],
#  126698.0: ['Orange County Conservation Corps Charter', 'Oakendell Community'],
#  126722.0: ['East Palo Alto Academy', 'Oakendell Community'],
#  126748.0: ['LPS Oakland R & D Campus', 'Oakendell Community'],
#  126870.0: ['San Joaquin Valley High', 'Oakendell Community'],
#  127100.0: ['Assurance Learning Academy', 'Oakendell Community'],
#  127159.0: ['Opportunities For Learning - Fresno', 'Oakendell Community'],
#  127209.0: ['Insight School of California', 'Oakendell Community'],
#  127217.0: ['Alliance Alice M. Baxter College-Ready High',
#   'Oakendell Community'],
#  127233.0: ['Young Adult Program', 'Oakendell Community'],
#  127241.0: ['Del Lago Academy - Campus of Applied Science',
#   'Oakendell Community'],
#  127316.0: ['Rancho Mirage High', 'Oakendell Community'],
#  127373.0: ['El Capitan High', 'Oakendell Community'],
#  127381.0: ['Ernest S. McBride, Sr. High', 'Oakendell Community'],
#  127423.0: ['Sage Creek High', 'Oakendell Community'],
#  127522.0: ['Optimist Charter', 'Oakendell Community'],
#  127530.0: ['KIPP San Francisco College Preparatory', 'Oakendell Community'],
#  127548.0: ['Summit Public School: Shasta', 'Oakendell Community'],
#  127563.0: ['Community Day', 'Oakendell Community'],
#  127647.0: ['e3 Civic High', 'Oakendell Community'],
#  127662.0: ['Stony Point Academy', 'Oakendell Community'],
#  127720.0: ['Rivercrest Preparatory', 'Oakendell Community'],
#  127787.0: ['Humanities and Arts (HARTS) Academy of Los Angeles',
#   'Oakendell Community'],
#  127795.0: ['Contreras Learning Center-School of Social Justice',
#   'Oakendell Community'],
#  127803.0: ['Early College Academy-LA Trade Tech College',
#   'Oakendell Community'],
#  127845.0: ['Lynwood Alternative', 'Oakendell Community'],
#  127852.0: ['Executive Preparatory Academy of Finance', 'Oakendell Community'],
#  127860.0: ['Alpha Charter', 'Oakendell Community'],
#  127878.0: ['Pathways Community', 'Oakendell Community'],
#  127894.0: ['Valor Academy High', 'Oakendell Community'],
#  127902.0: ['Squaw Valley Preparatory', 'Oakendell Community'],
#  127910.0: ['Camino Nuevo High #2', 'Oakendell Community'],
#  127944.0: ['Silver Oak High Public Montessori Charter',
#   'Oakendell Community'],
#  128157.0: ['Gateway to College Academy', 'Oakendell Community'],
#  128165.0: ['Peninsula High', 'Oakendell Community'],
#  128215.0: ['Harvest High', 'Oakendell Community'],
#  128314.0: ['Legacy High', 'Oakendell Community'],
#  128363.0: ['College Prep High', 'Oakendell Community'],
#  128397.0: ['Come Back Kids', 'Oakendell Community'],
#  128447.0: ['The Education Corps', 'Oakendell Community'],
#  128454.0: ['College Bridge Academy', 'Oakendell Community'],
#  128488.0: ['Family First Charter', 'Oakendell Community'],
#  128496.0: ['New Opportunities Charter', 'Oakendell Community'],
#  128520.0: ['San Diego County Community', 'Oakendell Community'],
#  128538.0: ['San Diego County Court', 'Oakendell Community'],
#  128645.0: ['Sawtooth Ridge Community', 'Oakendell Community'],
#  128652.0: ['Margaret J. Kemp', 'Oakendell Community'],
#  128736.0: ['Opportunities for Learning - Duarte', 'Oakendell Community'],
#  128777.0: ['Gateway College and Career Academy', 'Oakendell Community'],
#  128793.0: ['MERIT Academy', 'Oakendell Community'],
#  128819.0: ['REACH Academy', 'Oakendell Community'],
#  128900.0: ['South Bay Academy Community Day', 'Oakendell Community'],
#  128967.0: ['Mountain House High', 'Oakendell Community'],
#  128983.0: ['Eagle Creek', 'Oakendell Community'],
#  129023.0: ['Stanislaus Alternative Charter', 'Oakendell Community'],
#  129320.0: ['Bonsall High', 'Oakendell Community'],
#  129536.0: ['Boyle Heights STEM High', 'Oakendell Community'],
#  129585.0: ['NAVA College Preparatory Academy', 'Oakendell Community'],
#  129627.0: ['TEACH Tech Charter High', 'Oakendell Community'],
#  129684.0: ['Summit Public School K2', 'Oakendell Community'],
#  129759.0: ['Design Tech High', 'Oakendell Community'],
#  129775.0: ['Banning Academies of Creative and Innovative Sciences (BACIS)',
#   'Oakendell Community'],
#  129908.0: ['Delta Keys Charter', 'Oakendell Community'],
#  130047.0: ['Roy A. Johnson High', 'Oakendell Community'],
#  130054.0: ['Newark Memorial High', 'Oakendell Community'],
#  130062.0: ['American High', 'Oakendell Community'],
#  130096.0: ['Foothill High', 'Oakendell Community'],
#  130138.0: ['Robertson High (Continuation)', 'Oakendell Community'],
#  130146.0: ['Rudsdale Continuation', 'Oakendell Community'],
#  130179.0: ['Street Academy (Alternative)', 'Oakendell Community'],
#  130229.0: ['Alameda High', 'Oakendell Community'],
#  130252.0: ['Village High', 'Oakendell Community'],
#  130286.0: ['Millennium High Alternative', 'Oakendell Community'],
#  130294.0: ['MacGregor High (Continuation)', 'Oakendell Community'],
#  130401.0: ['Alameda County Juvenile Hall/Court', 'Oakendell Community'],
#  130419.0: ['Alameda County Community', 'Oakendell Community'],
#  130435.0: ['Vista Alternative', 'Oakendell Community'],
#  130450.0: ['Albany High', 'Oakendell Community'],
#  130583.0: ['Amador Valley High', 'Oakendell Community'],
#  130625.0: ['Alternatives in Action', 'Oakendell Community'],
#  130708.0: ['Sierra Vista Charter High', 'Oakendell Community'],
#  130724.0: ['Success One!', 'Oakendell Community'],
#  130757.0: ['Highlands Community Charter', 'Oakendell Community'],
#  130823.0: ['EPIC de Cesar Chavez', 'Oakendell Community'],
#  130849.0: ['Arroyo High', 'Oakendell Community'],
#  130856.0: ['Luis Valdez Leadership Academy', 'Oakendell Community'],
#  130864.0: ['New Jerusalem Online', 'Oakendell Community'],
#  130963.0: ['Adult Transition Program', 'Oakendell Community'],
#  130997.0: ['Sylmar Biotech Health Academy', 'Oakendell Community'],
#  131037.0: ['Rising Sun', 'Oakendell Community'],
#  131086.0: ['Ripperdan Community Day', 'Oakendell Community'],
#  131094.0: ['Valley Academy', 'Oakendell Community'],
#  131128.0: ['Da Vinci Communications', 'Oakendell Community'],
#  131144.0: ['Diego Springs Academy', 'Oakendell Community'],
#  131177.0: ['Berkeley High', 'Oakendell Community'],
#  131185.0: ['Fusion Charter', 'Oakendell Community'],
#  131243.0: ['Phoenix Rising High', 'Oakendell Community'],
#  131383.0: ['SIATech Academy South', 'Oakendell Community'],
#  131557.0: ['Method Schools High', 'Oakendell Community'],
#  131573.0: ['Burbank Unified Independent Learning Academy (BUILA)',
#   'Oakendell Community'],
#  131599.0: ['Marysville Community Day', 'Oakendell Community'],
#  131698.0: ['Rancho Campana High', 'Oakendell Community'],
#  131821.0: ['Collegiate Charter High of Los Angeles', 'Oakendell Community'],
#  131938.0: ['Clear Passage Educational Center', 'Oakendell Community'],
#  131953.0: ['Lassen Community Day', 'Oakendell Community'],
#  131995.0: ['B. Roberto Cruz Leadership Academy', 'Oakendell Community'],
#  132027.0: ['University Preparatory Value High', 'Oakendell Community'],
#  132126.0: ['Bert Corona Charter High', 'Oakendell Community'],
#  132134.0: ['Phillip J Patino School of Entrepreneurship',
#   'Oakendell Community'],
#  132167.0: ['Aspire Community Day', 'Oakendell Community'],
#  132225.0: ['Castro Valley High', 'Oakendell Community'],
#  132233.0: ['John Henry High', 'Oakendell Community'],
#  132274.0: ['Alpha Cindy Avitia High', 'Oakendell Community'],
#  132282.0: ['Ednovate - East College Prep', 'Oakendell Community'],
#  132308.0: ['Pinnacles Community', 'Oakendell Community'],
#  132324.0: ['Eunice Sato Academy of Math & Science', 'Oakendell Community'],
#  132365.0: ['Delta Launch Charter', 'Oakendell Community'],
#  132498.0: ['Encore High School for the Arts - Riverside',
#   'Oakendell Community'],
#  132548.0: ['IDEA Center', 'Oakendell Community'],
#  132555.0: ['Conservatory of Vocal/Instrumental Arts High',
#   'Oakendell Community'],
#  132647.0: ['Shasta County Independent Study Charter', 'Oakendell Community'],
#  132670.0: ['Del Valle Continuation High', 'Oakendell Community'],
#  132688.0: ['Dewey Academy', 'Oakendell Community'],
#  132704.0: ['Dublin High', 'Oakendell Community'],
#  132720.0: ['Needles Community Day', 'Oakendell Community'],
#  132738.0: ['Dr Bob Forinash Community Day', 'Oakendell Community'],
#  132746.0: ['Emery Secondary', 'Oakendell Community'],
#  132761.0: ['California Prep Sutter 8-12', 'Oakendell Community'],
#  132860.0: ['Kings Valley Academy', 'Oakendell Community'],
#  132910.0: ['College and Career Preparatory Academy', 'Oakendell Community'],
#  132969.0: ['Compton Early College High', 'Oakendell Community'],
#  133009.0: ['Brenkwitz High', 'Oakendell Community'],
#  133116.0: ['Insight @ San Joaquin', 'Oakendell Community'],
#  133306.0: ['Orange Vista High', 'Oakendell Community'],
#  133397.0: ['Granada High', 'Oakendell Community'],
#  133405.0: ['Portola High', 'Oakendell Community'],
#  133629.0: ['Hayward High', 'Oakendell Community'],
#  133637.0: ['Summit Public School: Tamalpais', 'Oakendell Community'],
#  133793.0: ['Accelerated Charter High', 'Oakendell Community'],
#  133827.0: ['Ceres Special Education', 'Oakendell Community'],
#  133835.0: ['Ellen Ochoa Prep Academy', 'Oakendell Community'],
#  133868.0: ['Rise Kohyang High', 'Oakendell Community'],
#  133876.0: ['Castro Valley Virtual Academy', 'Oakendell Community'],
#  133900.0: ['Prepa Tec Los Angeles High', 'Oakendell Community'],
#  133959.0: ['Unity Middle College High', 'Oakendell Community'],
#  133983.0: ['Ednovate - Legacy College Prep.', 'Oakendell Community'],
#  134189.0: ['Summit Secondary', 'Oakendell Community'],
#  134213.0: ['Come Back Butte Charter', 'Oakendell Community'],
#  134254.0: ['Pinnacle Academy Charter - Independent Study',
#   'Oakendell Community'],
#  134270.0: ['Irvington High', 'Oakendell Community'],
#  134304.0: ['Island High (Continuation)', 'Oakendell Community'],
#  134320.0: ['Riverside County Education Academy - Indio',
#   'Oakendell Community'],
#  134346.0: ['Intellectual Virtues Academy', 'Oakendell Community'],
#  134379.0: ['Imperial Pathways Charter', 'Oakendell Community'],
#  134452.0: ['John F. Kennedy High', 'Oakendell Community'],
#  134528.0: ['Lincoln High (Continuation)', 'Oakendell Community'],
#  134536.0: ['Livermore High', 'Oakendell Community'],
#  134569.0: ['Gold Ridge Educational Center', 'Oakendell Community'],
#  134585.0: ['Pathways Academy Charter Adult Education', 'Oakendell Community'],
#  134619.0: ['Empower Generations', 'Oakendell Community'],
#  134668.0: ['James Logan High', 'Oakendell Community'],
#  134841.0: ['Orange County Workforce Innovation High', 'Oakendell Community'],
#  134858.0: ['California School of the Arts - San Gabriel Valley',
#   'Oakendell Community'],
#  134890.0: ['San Diego Workforce Innovation High', 'Oakendell Community'],
#  134924.0: ['Berkeley Technology Academy', 'Oakendell Community'],
#  134981.0: ['Scholar Plus Online Learning', 'Oakendell Community'],
#  135061.0: ['Alvord Alternative Continuation High', 'Oakendell Community'],
#  135087.0: ['Opportunity Youth Academy', 'Oakendell Community'],
#  135095.0: ['Ernest Kimme Charter Academy for Independent Learning',
#   'Oakendell Community'],
#  135244.0: ['Mission San Jose High', 'Oakendell Community'],
#  135269.0: ['Oxford Day Academy', 'Oakendell Community'],
#  135319.0: ['Mt. Eden High', 'Oakendell Community'],
#  135335.0: ['Woodruff Academy', 'Oakendell Community'],
#  135426.0: ['Bridgepoint High (Continuation)', 'Oakendell Community'],
#  135525.0: ['Richard D. Browning High', 'Oakendell Community'],
#  135533.0: ['Redwood Continuation High', 'Oakendell Community'],
#  135582.0: ["LA's Promise Charter High #1", 'Oakendell Community'],
#  135632.0: ['WISH Academy High', 'Oakendell Community'],
#  135715.0: ['Ednovate - Esperanza College Prep', 'Oakendell Community'],
#  135723.0: ['Ednovate - Brio College Prep', 'Oakendell Community'],
#  135772.0: ['Meraki High', 'Oakendell Community'],
#  135814.0: ['Peninsula High (Continuation)', 'Oakendell Community'],
#  135905.0: ['Oakland High', 'Oakendell Community'],
#  135939.0: ['Washington Middle College High', 'Oakendell Community'],
#  135970.0: ['Mission Early College High', 'Oakendell Community'],
#  135988.0: ['RISE High', 'Oakendell Community'],
#  136028.0: ['Delta Keys Charter #2', 'Oakendell Community'],
#  136051.0: ['Oakland Technical High', 'Oakendell Community'],
#  136077.0: ['Grossmont Secondary', 'Oakendell Community'],
#  136119.0: ['Animo City of Champions Charter High', 'Oakendell Community'],
#  136135.0: ['Delta Charter Online No.2', 'Oakendell Community'],
#  136192.0: ['School of Universal Learning (SOUL)', 'Oakendell Community'],
#  136218.0: ['Uplift California North Charter', 'Oakendell Community'],
#  136226.0: ['Opportunity Academy', 'Oakendell Community'],
#  136234.0: ['Lemoore Online College Preparatory High', 'Oakendell Community'],
#  136291.0: ['Career Technical Education Charter', 'Oakendell Community'],
#  136432.0: ['Alta Vista Innovation High', 'Oakendell Community'],
#  136473.0: ['Sweetwater Secondary', 'Oakendell Community'],
#  136499.0: ['Ambassador Phillip V. Sanchez II Public Charter',
#   'Oakendell Community'],
#  136507.0: ['Crescent Valley Public Charter II', 'Oakendell Community'],
#  136515.0: ['Piedmont High', 'Oakendell Community'],
#  136523.0: ['Crescent View South II', 'Oakendell Community'],
#  136556.0: ['Kings Valley Academy II', 'Oakendell Community'],
#  136572.0: ['Santa Cruz County Career Advancement Charter',
#   'Oakendell Community'],
#  136614.0: ['Diego Hills Central Public Charter', 'Oakendell Community'],
#  136648.0: ['Options for Youth-Acton', 'Oakendell Community'],
#  136705.0: ['Odyssey STEM Academy', 'Oakendell Community'],
#  136804.0: ['Oxnard Middle College High', 'Oakendell Community'],
#  136820.0: ['Achieve Charter High', 'Oakendell Community'],
#  136887.0: ['Sanhedrin Alternative', 'Oakendell Community'],
#  136952.0: ['Entrepreneur High', 'Oakendell Community'],
#  137042.0: ['Mt. SAC Early College Academy at West Covina',
#   'Oakendell Community'],
#  137067.0: ['High Tech High Mesa', 'Oakendell Community'],
#  137083.0: ['University Pathways Medical Magnet Academy',
#   'Oakendell Community'],
#  137091.0: ['University Pathways Public Service Academy',
#   'Oakendell Community'],
#  137109.0: ['Diego Valley East Public Charter', 'Oakendell Community'],
#  137281.0: ['SAVA - Sacramento Academic and Vocational Academy - EGUSD',
#   'Oakendell Community'],
#  137315.0: ['KIPP Navigate College Prep', 'Oakendell Community'],
#  137406.0: ['SAVA - Sacramento Academic and Vocational Academy - SCUSD',
#   'Oakendell Community'],
#  137414.0: ['Corning Independent Study', 'Oakendell Community'],
#  137422.0: ['Yolo County Career Academy', 'Oakendell Community'],
#  137562.0: ['Matrix for Success Academy', 'Oakendell Community'],
#  137588.0: ['San Leandro High', 'Oakendell Community'],
#  137612.0: ['Valley International Preparatory High', 'Oakendell Community'],
#  137620.0: ['Pathways for Adult Life Skills', 'Oakendell Community'],
#  137638.0: ['Lakeview Leadership Academy', 'Oakendell Community'],
#  137745.0: ['Royal Sunset (Continuation)', 'Oakendell Community'],
#  137778.0: ['Humboldt Virtual Academy', 'Oakendell Community'],
#  137810.0: ['San Lorenzo High', 'Oakendell Community'],
#  137869.0: ['Excelsior Charter School Corona-Norco', 'Oakendell Community'],
#  137901.0: ['Hanford Online Charter', 'Oakendell Community'],
#  137943.0: ['Skyline High', 'Oakendell Community'],
#  137950.0: ['Marconi Learning Academy', 'Oakendell Community'],
#  137968.0: ['Porterville Military Academy', 'Oakendell Community'],
#  138032.0: ['Come Back Charter', 'Oakendell Community'],
#  138081.0: ['Maidu Virtual Charter Academy', 'Oakendell Community'],
#  138115.0: ['Crossroads High', 'Oakendell Community'],
#  138123.0: ['Goodwill Independent Study', 'Oakendell Community'],
#  138164.0: ['Dublin Unified Transition Program', 'Oakendell Community'],
#  138255.0: ['Paso Robles Community', 'Oakendell Community'],
#  138263.0: ['North Bay Met Academy', 'Oakendell Community'],
#  138289.0: ['Latitude 37.8 High', 'Oakendell Community'],
#  138339.0: ['Tennyson High', 'Oakendell Community'],
#  138453.0: ['Valley High (Continuation)', 'Oakendell Community'],
#  138669.0: ['Da Vinci RISE High', 'Oakendell Community'],
#  138693.0: ['Washington High', 'Oakendell Community'],
#  230011.0: ['Alpine County Opportunity', 'Oakendell Community'],
#  330019.0: ['Independence High (Continuation)', 'Oakendell Community'],
#  330027.0: ['Pine Grove Youth Conservation Camp', 'Oakendell Community'],
#  330035.0: ['County Community', 'Oakendell Community'],
#  330050.0: ['North Star Independent Study', 'Oakendell Community'],
#  330068.0: ['Amador County Special Education', 'Oakendell Community'],
#  330753.0: ['Amador High', 'Oakendell Community'],
#  334755.0: ['Argonaut High', 'Oakendell Community'],
#  430066.0: ['Table Mountain', 'Oakendell Community'],
#  430108.0: ['Honey Run Academy Secondary', 'Oakendell Community'],
#  430140.0: ['Oroville High Community Day', 'Oakendell Community'],
# ...
#  630012.0: ['Colusa Alternative High (Continuation)', 'Oakendell Community'],
#  630038.0: ['Mid Valley High (Continuation)', 'Oakendell Community'],
#  630087.0: ['Arbuckle Alternative High (Continuation)', 'Oakendell Community'],
#  630111.0: ['S. William Abel Community', 'Oakendell Community'],
#  631259.0: ['Colusa High', 'Oakendell Community'],
#  634758.0: ['Maxwell Sr High', 'Oakendell Community'],
#  635250.0: ['Pierce High', 'Oakendell Community'],
#  637504.0: ['Williams Junior/Senior High', 'Oakendell Community'],
#  730044.0: ['Northgate High', 'Oakendell Community'],
#  730051.0: ['California High', 'Oakendell Community'],
#  730101.0: ['Live Oak High (Continuation)', 'Oakendell Community'],
#  730184.0: ['Black Diamond High (Continuation)', 'Oakendell Community'],
#  730283.0: ['Acalanes High', 'Oakendell Community'],
#  730291.0: ['Middle College High', 'Oakendell Community'],
#  730325.0: ['Vista High (Alternative)', 'Oakendell Community'],
#  730333.0: ['Gateway High (Continuation)', 'Oakendell Community'],
#  730358.0: ['Prospect High (Continuation)', 'Oakendell Community'],
#  730416.0: ['Crossroads High (Alternative)', 'Oakendell Community'],
#  730424.0: ['Summit High (Continuation)', 'Oakendell Community'],
#  730440.0: ['Vicente Martinez High', 'Oakendell Community'],
#  730457.0: ['Freedom High', 'Oakendell Community'],
#  730465.0: ['Deer Valley High', 'Oakendell Community'],
#  730481.0: ['Bridges', 'Oakendell Community'],
#  730549.0: ['Alhambra Senior High', 'Oakendell Community'],
#  730572.0: ['Independence High', 'Oakendell Community'],
#  730598.0: ['Hercules High', 'Oakendell Community'],
#  730614.0: ['Golden Gate Community', 'Oakendell Community'],
#  730655.0: ['Diablo Community Day', 'Oakendell Community'],
#  730861.0: ['Antioch High', 'Oakendell Community'],
#  731125.0: ['Campolindo High', 'Oakendell Community'],
#  731380.0: ['Clayton Valley Charter High', 'Oakendell Community'],
#  731646.0: ['College Park High', 'Oakendell Community'],
#  731836.0: ['Concord High', 'Oakendell Community'],
#  732164.0: ['De Anza High', 'Oakendell Community'],
#  732941.0: ['El Cerrito High', 'Oakendell Community'],
#  733253.0: ['Greenwood Academy', 'Oakendell Community'],
#  733659.0: ['John F. Kennedy High', 'Oakendell Community'],
#  733725.0: ['Las Lomas High', 'Oakendell Community'],
#  733980.0: ['Liberty High', 'Oakendell Community'],
#  733998.0: ['La Paloma High (Continuation)', 'Oakendell Community'],
#  734244.0: ['Miramonte High', 'Oakendell Community'],
#  734368.0: ['Monte Vista High', 'Oakendell Community'],
#  734566.0: ['Mt. Diablo High', 'Oakendell Community'],
#  734764.0: ['Olympic Continuation High', 'Oakendell Community'],
#  735316.0: ['Pinole Valley High', 'Oakendell Community'],
#  735407.0: ['Pittsburg Senior High', 'Oakendell Community'],
#  735902.0: ['Richmond High', 'Oakendell Community'],
#  736504.0: ['San Ramon Valley High', 'Oakendell Community'],
#  736819.0: ['Del Amigo High (Continuation)', 'Oakendell Community'],
#  737023.0: ['John Swett High', 'Oakendell Community'],
#  737619.0: ['Willow High', 'Oakendell Community'],
#  737809.0: ['Ygnacio Valley High', 'Oakendell Community'],
#  830042.0: ['Del Norte Community', 'Oakendell Community'],
#  833004.0: ['Del Norte High', 'Oakendell Community'],
#  836205.0: ['Sunset High', 'Oakendell Community'],
#  930016.0: ['Golden Ridge', 'Oakendell Community'],
#  930040.0: ['Mt. Tallac High', 'Oakendell Community'],
#  930073.0: ['Golden Sierra Junior Senior High', 'Oakendell Community'],
#  930081.0: ['Oak Ridge High', 'Oakendell Community'],
#  930099.0: ['Divide High', 'Oakendell Community'],
#  930107.0: ['Transitional Learning Center (Continuation)',
#   'Oakendell Community'],
#  930123.0: ['Charter Community School Home Study Academy',
#   'Oakendell Community'],
#  930131.0: ['Rite of Passage', 'Oakendell Community'],
#  930164.0: ['Union Mine High', 'Oakendell Community'],
#  930214.0: ['EDUHSD Virtual Academy at Shenandoah', 'Oakendell Community'],
#  930222.0: ['Vista High', 'Oakendell Community'],
#  932756.0: ['El Dorado High', 'Oakendell Community'],
#  934554.0: ['Independence Continuation', 'Oakendell Community'],
#  936302.0: ['Ponderosa High', 'Oakendell Community'],
#  937805.0: ['South Tahoe High', 'Oakendell Community'],
#  1030113.0: ['Cambridge High', 'Oakendell Community'],
#  1030121.0: ['Firebaugh High', 'Oakendell Community'],
#  1030139.0: ['Sandy Bluffs Alternative Education Center',
#   'Oakendell Community'],
#  1030147.0: ['El Puente High', 'Oakendell Community'],
#  1030196.0: ['Clovis West High', 'Oakendell Community'],
#  1030253.0: ['Horizon High', 'Oakendell Community'],
#  1030261.0: ['Mendota Continuation High', 'Oakendell Community'],
#  1030279.0: ['Bullard High', 'Oakendell Community'],
#  1030295.0: ['Erma Duncan Polytechnical High', 'Oakendell Community'],
#  1030337.0: ['Alice M. Worsley', 'Oakendell Community'],
#  1030352.0: ['Rio Del Rey High (Continuation)', 'Oakendell Community'],
#  1030477.0: ['Chesnut High (Continuation)', 'Oakendell Community'],
#  1030493.0: ['Mendota High', 'Oakendell Community'],
#  1030501.0: ['Buchanan High', 'Oakendell Community'],
#  1030535.0: ['Caruthers High', 'Oakendell Community'],
#  1030543.0: ['MARC High', 'Oakendell Community'],
#  1030584.0: ['Cambridge Continuation High', 'Oakendell Community'],
#  1030626.0: ['Central High East Campus', 'Oakendell Community'],
#  1030642.0: ['School of Unlimited Learning', 'Oakendell Community'],
#  1030675.0: ['Sunnyside High', 'Oakendell Community'],
#  1030683.0: ['Clovis East High', 'Oakendell Community'],
#  1030717.0: ['Florence E. Rata', 'Oakendell Community'],
#  1030824.0: ['Community Day', 'Oakendell Community'],
#  1030840.0: ['Carter G. Woodson Public Charter', 'Oakendell Community'],
#  1030873.0: ['Miles W. Culwell Community Day', 'Oakendell Community'],
#  1030899.0: ['Violet Heintz Education Academy', 'Oakendell Community'],
#  1031004.0: ['Gateway High (Continuation)', 'Oakendell Community'],
#  1031053.0: ['Clovis High', 'Oakendell Community'],
#  1031376.0: ['Coalinga High', 'Oakendell Community'],
#  1031632.0: ['Dewolf Continuation High', 'Oakendell Community'],
#  1031897.0: ['Edison High', 'Oakendell Community'],
#  1031954.0: ['Fowler Academy Continuation', 'Oakendell Community'],
#  1032150.0: ['Fowler High', 'Oakendell Community'],
#  1032507.0: ['Fresno High', 'Oakendell Community'],
#  1032911.0: ['Herbert Hoover High', 'Oakendell Community'],
#  1033422.0: ['Enterprise High', 'Oakendell Community'],
#  1033430.0: ['Kerman High', 'Oakendell Community'],
#  1033695.0: ['Kingsburg High', 'Oakendell Community'],
#  1033729.0: ['Oasis Continuation High', 'Oakendell Community'],
#  1033950.0: ['Laton High', 'Oakendell Community'],
#  1034214.0: ['McLane High', 'Oakendell Community'],
#  1034990.0: ['Parlier High', 'Oakendell Community'],
#  1035112.0: ['Pershing Continuation High', 'Oakendell Community'],
#  1035310.0: ['Reedley High', 'Oakendell Community'],
#  1035575.0: ['Riverdale High', 'Oakendell Community'],
#  1035831.0: ['Roosevelt High', 'Oakendell Community'],
#  1036086.0: ['Kings River High (Continuation)', 'Oakendell Community'],
#  1036094.0: ['Sanger High', 'Oakendell Community'],
#  1036607.0: ['Heartland High (Continuation)', 'Oakendell Community'],
#  1036672.0: ['Selma High', 'Oakendell Community'],
#  1036938.0: ['Sierra High', 'Oakendell Community'],
#  1037456.0: ['Tranquillity High', 'Oakendell Community'],
#  1038298.0: ['Easton Continuation High', 'Oakendell Community'],
#  1038306.0: ['Washington High', 'Oakendell Community'],
#  1130012.0: ['North Valley High (Continuation)', 'Oakendell Community'],
#  1130038.0: ['Willows Community High', 'Oakendell Community'],
#  1130046.0: ['Bidwell Point High (Continuation)', 'Oakendell Community'],
#  1130053.0: ['Ella Barkley High', 'Oakendell Community'],
#  1130087.0: ['Glenn County Juvenile Court', 'Oakendell Community'],
#  1130145.0: ['Orland Community Day', 'Oakendell Community'],
#  1132109.0: ['Elk Creek Junior-Senior High', 'Oakendell Community'],
#  1132851.0: ['Willows High', 'Oakendell Community'],
#  1133701.0: ['Hamilton High', 'Oakendell Community'],
#  1135656.0: ['Orland High', 'Oakendell Community'],
#  1136209.0: ['Princeton Junior-Senior High', 'Oakendell Community'],
#  1230010.0: ['Osprey Learning Center', 'Oakendell Community'],
#  1230028.0: ['Captain John Continuation High', 'Oakendell Community'],
#  1230044.0: ['Pacific Coast High (Continuation)', 'Oakendell Community'],
#  1230051.0: ['Tsurai High (Continuation)', 'Oakendell Community'],
#  1230085.0: ['Mattole Triple Junction High', 'Oakendell Community'],
#  1230705.0: ['Arcata High', 'Oakendell Community'],
#  1232057.0: ['Zoe Barnum High', 'Oakendell Community'],
#  1232206.0: ['Eureka Senior High', 'Oakendell Community'],
#  1232909.0: ['Ferndale High', 'Oakendell Community'],
#  1233352.0: ['East High (Continuation)', 'Oakendell Community'],
#  1233402.0: ['Fortuna Union High', 'Oakendell Community'],
#  1234004.0: ['Hoopa Valley High', 'Oakendell Community'],
#  1235209.0: ['McKinleyville High', 'Oakendell Community'],
#  1237007.0: ['South Fork Junior - Senior High', 'Oakendell Community'],
#  1330018.0: ['Bill M. Manes High', 'Oakendell Community'],
#  1330117.0: ['Imperial County Juvenile Hall/Community', 'Oakendell Community'],
#  1330133.0: ['Southwest High', 'Oakendell Community'],
#  1330141.0: ['Renaissance', 'Oakendell Community'],
#  1331115.0: ['Imperial Ave. Holbrook High', 'Oakendell Community'],
#  1331354.0: ['Desert Valley High (Continuation)', 'Oakendell Community'],
#  1331404.0: ['Brawley Union High', 'Oakendell Community'],
#  1332154.0: ['Aurora High (Continuation)', 'Oakendell Community'],
#  1332204.0: ['Calexico High', 'Oakendell Community'],
#  1332501.0: ['Calipatria High', 'Oakendell Community'],
#  1333004.0: ['Central Union High', 'Oakendell Community'],
#  1333558.0: ['Desert Oasis High (Continuation)', 'Oakendell Community'],
#  1335306.0: ['Holtville High', 'Oakendell Community'],
#  1335900.0: ['Imperial High', 'Oakendell Community'],
#  1337138.0: ['Sam Webb Continuation', 'Oakendell Community'],
#  1337609.0: ['San Pasqual Valley High', 'Oakendell Community'],
#  1430057.0: ['Palisade Glacier High (Continuation)', 'Oakendell Community'],
#  1430065.0: ['Shoshone High (Continuation)', 'Oakendell Community'],
#  1430073.0: ['Jill Kinmont Boothe', 'Oakendell Community'],
#  1430107.0: ['Keith B. Bright High (Juvenile Hall)', 'Oakendell Community'],
#  1431352.0: ['Big Pine High', 'Oakendell Community'],
#  1431600.0: ['Bishop Union High', 'Oakendell Community'],
#  1434901.0: ['Lone Pine High', 'Oakendell Community'],
#  1436203.0: ['Owens Valley High', 'Oakendell Community'],
#  1438308.0: ['Death Valley High Academy', 'Oakendell Community'],
#  1530021.0: ['Central Valley High (Continuation)', 'Oakendell Community'],
#  1530039.0: ['Rare Earth High (Continuation)', 'Oakendell Community'],
#  1530047.0: ['Nueva Continuation High', 'Oakendell Community'],
#  1530054.0: ['Mesquite Continuation High', 'Oakendell Community'],
#  1530112.0: ['Vista West Continuation High', 'Oakendell Community'],
#  1530138.0: ['Buena Vista High (Continuation)', 'Oakendell Community'],
#  1530146.0: ['San Joaquin High (Continuation)', 'Oakendell Community'],
#  1530229.0: ['McFarland Independent', 'Oakendell Community'],
#  1530245.0: ['Monroe High (Continuation)', 'Oakendell Community'],
#  1530252.0: ['Arvin High', 'Oakendell Community'],
#  1530344.0: ['Stockdale High', 'Oakendell Community'],
#  1530351.0: ['Wasco Independence High', 'Oakendell Community'],
#  1530369.0: ['Centennial High', 'Oakendell Community'],
#  1530385.0: ['Ridgeview High', 'Oakendell Community'],
#  1530401.0: ['Frazier Mountain High', 'Oakendell Community'],
#  1530435.0: ['Kern Workforce 2000 Academy', 'Oakendell Community'],
#  1530476.0: ['Liberty High', 'Oakendell Community'],
#  1530708.0: ['Bakersfield High', 'Oakendell Community'],
#  1530997.0: ['Boron Junior-Senior High', 'Oakendell Community'],
#  1531367.0: ['Burroughs High', 'Oakendell Community'],
#  1531656.0: ['Valley High', 'Oakendell Community'],
#  1531672.0: ['Delano High', 'Oakendell Community'],
#  1531987.0: ['Desert Junior-Senior High', 'Oakendell Community'],
#  1532290.0: ['East Bakersfield High', 'Oakendell Community'],
#  1532605.0: ['Foothill High', 'Oakendell Community'],
#  1533330.0: ['Highland High', 'Oakendell Community'],
#  1533538.0: ['Kern Valley High', 'Oakendell Community'],
#  1533843.0: ['Maricopa High', 'Oakendell Community'],
#  1534155.0: ['McFarland High', 'Oakendell Community'],
#  1534460.0: ['Mojave Jr./Sr. High', 'Oakendell Community'],
#  1534775.0: ['North High', 'Oakendell Community'],
#  1534957.0: ['Rosamond High Early College Campus', 'Oakendell Community'],
#  1535087.0: ['Shafter High', 'Oakendell Community'],
#  1535392.0: ['South High', 'Oakendell Community'],
#  1535905.0: ['Taft Union High', 'Oakendell Community'],
#  1536135.0: ['Tehachapi High', 'Oakendell Community'],
#  1536325.0: ['Vista Continuation High', 'Oakendell Community'],
#  1536440.0: ['Wasco High', 'Oakendell Community'],
#  1536606.0: ['West High', 'Oakendell Community'],
#  1630011.0: ['Jamison (Donald C.) High (Continuation)', 'Oakendell Community'],
#  1630060.0: ['Hanford Night (Continuation)', 'Oakendell Community'],
#  1630078.0: ['Sunrise High (Continuation)', 'Oakendell Community'],
#  1630102.0: ['J. C. Montgomery', 'Oakendell Community'],
#  1630110.0: ['Adelante High', 'Oakendell Community'],
#  1630151.0: ['Hanford Community Day', 'Oakendell Community'],
#  1630169.0: ['Hanford West High', 'Oakendell Community'],
#  1630185.0: ['Reef-Sunset Secondary Community Day', 'Oakendell Community'],
#  1630193.0: ['Kings County Community', 'Oakendell Community'],
#  1630953.0: ['Avenal High', 'Oakendell Community'],
#  1632140.0: ['Kings Lake Education Center', 'Oakendell Community'],
#  1632207.0: ['Corcoran High', 'Oakendell Community'],
#  1634245.0: ['Earl F. Johnson High (Continuation)', 'Oakendell Community'],
#  1634401.0: ['Hanford High', 'Oakendell Community'],
#  1635606.0: ['Lemoore High', 'Oakendell Community'],
#  1730019.0: ['Natural High (Continuation)', 'Oakendell Community'],
#  1730027.0: ['Carle (William C.) High (Continuation)', 'Oakendell Community'],
#  1730035.0: ['Loconoma Valley High', 'Oakendell Community'],
#  1730043.0: ['Ed Donaldson Education Center', 'Oakendell Community'],
#  1730050.0: ['Clover Valley High (Continuation)', 'Oakendell Community'],
#  1730159.0: ['Kelseyville Community Day', 'Oakendell Community'],
#  1730175.0: ['Upper Lake Community Day', 'Oakendell Community'],
#  1732304.0: ['Clear Lake High', 'Oakendell Community'],
#  1734359.0: ['Kelseyville High', 'Oakendell Community'],
#  1735000.0: ['Lower Lake High', 'Oakendell Community'],
#  1736008.0: ['Middletown High', 'Oakendell Community'],
#  1737006.0: ['Upper Lake High', 'Oakendell Community'],
#  1830058.0: ['Providence Jr./Sr. High', 'Oakendell Community'],
#  1833409.0: ['Herlong High', 'Oakendell Community'],
#  1833805.0: ['Lassen High', 'Oakendell Community'],
#  1930056.0: ['Cerritos High', 'Oakendell Community'],
#  1930064.0: ['William Tell Aggeler Opportunity High', 'Oakendell Community'],
#  1930080.0: ['Agoura High', 'Oakendell Community'],
#  1930106.0: ['Santana High (Continuation)', 'Oakendell Community'],
#  1930122.0: ['Century High', 'Oakendell Community'],
#  1930155.0: ['Schurr High', 'Oakendell Community'],
#  1930163.0: ['Alhambra High', 'Oakendell Community'],
#  1930213.0: ['Antelope Valley High', 'Oakendell Community'],
#  1930239.0: ['R. K. Lloyde High', 'Oakendell Community'],
#  1930288.0: ['Arcadia High', 'Oakendell Community'],
#  1930296.0: ['Harris Newmark Continuation', 'Oakendell Community'],
#  1930312.0: ['Arrow High (Continuation)', 'Oakendell Community'],
#  1930320.0: ['Arroyo High', 'Oakendell Community'],
#  1930338.0: ['Frontier High (Continuation)', 'Oakendell Community'],
#  1930353.0: ['Arena High (Continuation)', 'Oakendell Community'],
#  1930361.0: ['Artesia High', 'Oakendell Community'],
#  1930387.0: ['Central High', 'Oakendell Community'],
#  1930403.0: ['Whitney Young Continuation', 'Oakendell Community'],
#  1930429.0: ['View Park Continuation', 'Oakendell Community'],
#  1930486.0: ['Moneta Continuation', 'Oakendell Community'],
#  ...}

# %%
#function that drops DistrictName, SchoolName, CountyName from Dataframe
#we can drop the CharterYN column because there are is 1 unique value (All)
#^same goes for AggregateLevel column

def name_drop(df):
    df = df.drop(['SchoolName','DistrictName', 'CountyName','CharterYN','AggregateLevel'], axis = 1)
    return df

# %%
X1 = name_drop(X)
X1
# Out:
#      AcademicYear  CountryCode  DistrictCode  SchoolCode  CAR_RB  CAR_RI  \
# 0               1           32       10322.0    100057.0     NaN     NaN
# 1               2           32       10322.0    100057.0     NaN     NaN
# 2               3           32       10322.0    100057.0     NaN     NaN
# 3               1            1       61259.0    100065.0    19.0     NaN
# 4               2            1       61259.0    100065.0    31.3     NaN
# ...           ...          ...           ...         ...     ...     ...
# 6466            2           30       66464.0   6120356.0     NaN     NaN
# 6467            3           30       66464.0   6120356.0     0.0     NaN
# 6468            1            5       10058.0   9010745.0     NaN     NaN
# 6469            2            5       10058.0   9010745.0     NaN     NaN
# 6470            3            5       10058.0   9010745.0     NaN     NaN
#
#       CAR_RA  CAR_RF  CAR_RH  CAR_RD  ...  CAR_GF  CAR_GX  CAR_GZ  CAR_SE  \
# 0        NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 3        NaN     NaN    14.1    17.4  ...    16.9     NaN     NaN    24.1
# 4        NaN     NaN    13.5    15.4  ...    16.6     NaN     NaN    16.7
# ...      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 6466     NaN     NaN     9.1     5.4  ...    10.1     NaN     NaN     NaN
# 6467     NaN     NaN     4.6     4.5  ...     0.8     NaN     NaN     0.0
# 6468     NaN     NaN     0.0     NaN  ...     NaN     NaN     NaN     NaN
# 6469     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 6470     NaN     NaN     0.0     NaN  ...     NaN     NaN     NaN     NaN
#
#       CAR_SD  CAR_SS  CAR_SM  CAR_SF  CAR_SH  CAR_TA
# 0        NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN    90.0
# 3        7.4    15.0     NaN     NaN     NaN    14.7
# 4        8.3    15.0     NaN     NaN     NaN    14.5
# ...      ...     ...     ...     ...     ...     ...
# 6466    18.5    11.7     NaN     NaN     NaN     7.3
# 6467     2.6     5.0     NaN     NaN     NaN     3.3
# 6468     0.0     4.5     NaN     5.0     NaN     4.5
# 6469     7.7     0.0     NaN     0.0     NaN     5.0
# 6470     0.0     4.5     NaN     4.5     NaN     4.5
#
# [6471 rows x 24 columns]

# %%
#seperate academic year into one-hot-encoded values 
#2016 == Year1
oneHot = pd.get_dummies(X1.AcademicYear)
X1 = pd.concat([oneHot, X1], axis=1)
X1 = X1.drop('AcademicYear', axis = 1)
X1
# Out:
#       1  2  3  CountryCode  DistrictCode  SchoolCode  CAR_RB  CAR_RI  CAR_RA  \
# 0     1  0  0           32       10322.0    100057.0     NaN     NaN     NaN
# 1     0  1  0           32       10322.0    100057.0     NaN     NaN     NaN
# 2     0  0  1           32       10322.0    100057.0     NaN     NaN     NaN
# 3     1  0  0            1       61259.0    100065.0    19.0     NaN     NaN
# 4     0  1  0            1       61259.0    100065.0    31.3     NaN     NaN
# ...  .. .. ..          ...           ...         ...     ...     ...     ...
# 6466  0  1  0           30       66464.0   6120356.0     NaN     NaN     NaN
# 6467  0  0  1           30       66464.0   6120356.0     0.0     NaN     NaN
# 6468  1  0  0            5       10058.0   9010745.0     NaN     NaN     NaN
# 6469  0  1  0            5       10058.0   9010745.0     NaN     NaN     NaN
# 6470  0  0  1            5       10058.0   9010745.0     NaN     NaN     NaN
#
#       CAR_RF  ...  CAR_GF  CAR_GX  CAR_GZ  CAR_SE  CAR_SD  CAR_SS  CAR_SM  \
# 0        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN  ...    16.9     NaN     NaN    24.1     7.4    15.0     NaN
# 4        NaN  ...    16.6     NaN     NaN    16.7     8.3    15.0     NaN
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 6466     NaN  ...    10.1     NaN     NaN     NaN    18.5    11.7     NaN
# 6467     NaN  ...     0.8     NaN     NaN     0.0     2.6     5.0     NaN
# 6468     NaN  ...     NaN     NaN     NaN     NaN     0.0     4.5     NaN
# 6469     NaN  ...     NaN     NaN     NaN     NaN     7.7     0.0     NaN
# 6470     NaN  ...     NaN     NaN     NaN     NaN     0.0     4.5     NaN
#
#       CAR_SF  CAR_SH  CAR_TA
# 0        NaN     NaN     NaN
# 1        NaN     NaN     NaN
# 2        NaN     NaN    90.0
# 3        NaN     NaN    14.7
# 4        NaN     NaN    14.5
# ...      ...     ...     ...
# 6466     NaN     NaN     7.3
# 6467     NaN     NaN     3.3
# 6468     5.0     NaN     4.5
# 6469     0.0     NaN     5.0
# 6470     4.5     NaN     4.5
#
# [6471 rows x 26 columns]

# %% [markdown]
# ### Because many columns contain NaN values, we will use a Probalistic Principal Componet Analysis (PPCA) model to handle this missing data

# %%
### Because many columns contain NaN values, we will use a Probalistic Principal Componet Analysis (PPCA) model to handle this missing data

#Installation of pyppca: https://github.com/el-hult/pyppca#readme
#import ppca
def ppca(df,d,dia):
    """
    Implements probabilistic PCA for data with missing values,
    using a factorizing distribution over hidden states and hidden observations.
    Args:
        df:   (N by D) input DateFrame of data vectors; this is later converted to an N by D numpy array
        d:   (  int  ) dimension of latent space
        dia: (boolean) if True: print objective each step
    Returns:
        C:  (D by d ) C*C' + I*ss is covariance model, C has scaled principal directions as cols
        ss: ( float ) isotropic variance outside subspace
        M:  (D by 1 ) data mean
        X:  (N by d ) expected states
        Ye: (N by D ) expected complete observations (differs from Y if data is missing)
        Based on MATLAB code from J.J. VerBeek, 2006. http://lear.inrialpes.fr/~verbeek
    """
    df = df.astype(float)
    Y = df.to_numpy() #turns df to a NxD numpy array
    N, D = shape(Y)  # N observations in D dimensions (i.e. D is number of features, N is samples)
    threshold = 1E-4  # minimal relative change in objective function to continue
    hidden = np.isnan(Y)
    missing = hidden.sum()

    if missing > 0:
        M = nanmean(Y, axis=0)
    else:
        M = average(Y, axis=0)

    Ye = Y - repmat(M, N, 1)

    if missing > 0:
        Ye[hidden] = 0

    # initialize
    C = normal(loc=0.0, scale=1.0, size=(D, d))
    CtC = C.T @ C
    X = Ye @ C @ inv(CtC)
    recon = X @ C.T
    recon[hidden] = 0
    ss = np.sum((recon - Ye) ** 2) / (N * D - missing)

    count = 1
    old = np.inf

    # EM Iterations
    while (count):
        Sx = inv(eye(d) + CtC / ss)  # E-step, covariances
        ss_old = ss
        if missing > 0:
            proj = X @ C.T
            Ye[hidden] = proj[hidden]

        X = Ye @ C @ Sx / ss  # E-step: expected values

        SumXtX = X.T @ X  # M-step
        C = Ye.T @ X @ (SumXtX + N * Sx).T @ inv(((SumXtX + N * Sx) @ (SumXtX + N * Sx).T))
        CtC = C.T @ C
        ss = (np.sum((X @ C.T - Ye) ** 2) + N * np.sum(CtC * Sx) + missing * ss_old) / (N * D)
        # transform Sx determinant into numpy longdouble in order to deal with high dimensionality
        Sx_det = np.min(Sx).astype(np.longdouble) ** shape(Sx)[0] * det(Sx / np.min(Sx))
        objective = N * D + N * (D * log(ss) + tr(Sx) - log(Sx_det)) + tr(SumXtX) - missing * log(ss_old)

        rel_ch = np.abs(1 - objective / old)
        old = objective

        count = count + 1
        if rel_ch < threshold and count > 5:
            count = 0
        if dia:
            print(f"Objective: {objective:.2f}, Relative Change {rel_ch:.5f}")

    C = orth(C)
    covM = cov((Ye @ C).T)
    vals, vecs = eig(covM)
    ordr = np.argsort(vals)[::-1]
    vecs = vecs[:, ordr]

    C = C @ vecs
    X = Ye @ C

    # add data mean to expected complete data
    Ye = Ye + repmat(M, N, 1)

    return C, ss, M, X, Ye

# %%
shape(X1)
# Out:
# (6471, 26)

# %%
#returns C, ss, M, X, Ye given dimensions of reduced space
ppca_X = ppca(X1, 5, False)
ppca_X
# Out:
# /var/folders/xf/8808rrps3wb3r170fzcq_6t00000gn/T/ipykernel_37375/3885862556.py:29: RuntimeWarning: Mean of empty slice
#   M = nanmean(Y, axis=0)
# (array([[-8.34757769e-10, -2.12828455e-08],
#         [ 3.41300198e-10,  2.64682952e-08],
#         [ 4.93457446e-10, -4.91343566e-09],
#         [-4.92323639e-06,  3.01863602e-05],
#         [-1.60011337e-03,  9.99998687e-01],
#         [-9.99998720e-01, -1.60011352e-03],
#         [ 9.51784702e-07, -3.35153377e-05],
#         [ 2.63977375e-06, -1.93040993e-05],
#         [ 5.37453503e-07, -2.97101324e-05],
#         [-5.43051953e-08, -4.77544566e-06],
#         [-1.65501628e-07, -6.28818617e-05],
#         [ 1.56248202e-06, -2.81114382e-05],
#         [ 2.60193220e-07, -6.15578424e-06],
#         [ 1.10985171e-06, -6.12448834e-05],
#         [-1.57690493e-07, -7.92436567e-05],
#         [-8.36528876e-08, -7.39144545e-05],
#         [-2.17548498e-07, -9.92794308e-05],
#         [-7.24803138e-24,  1.87359141e-30],
#         [ 3.06254075e-23,  4.02386833e-31],
#         [-1.46471333e-08, -6.70871781e-05],
#         [-3.71807046e-07, -3.55759673e-05],
#         [-2.62538413e-07, -3.84293909e-05],
#         [ 1.55386360e-07, -7.27325273e-06],
#         [ 3.14881327e-07,  1.12828081e-04],
#         [-3.98828086e-07, -8.98666631e-05],
#         [-1.47730319e-07, -5.78243543e-05]]),
#  16447780.196933089,
#  array([3.34724154e-01, 3.32869726e-01, 3.32406120e-01, 2.82772369e+01,
#         6.32539317e+04, 2.18291383e+06, 2.82285828e+01, 2.81565708e+01,
#         9.95203870e+00, 8.00890472e+00, 2.97124959e+01, 1.96202191e+01,
#         1.93028409e+01, 1.97047567e+01, 2.84779295e+01, 2.92294297e+01,
#         3.05819461e+01,            nan,            nan, 2.87293578e+01,
#         3.32799697e+01, 3.21223741e+01, 1.57791719e+01, 4.09982816e+01,
#         3.88151088e+01, 3.06362226e+01]),
#  array([[ 2082938.8644985 ,   -49599.05483887],
#         [ 2082938.86449851,   -49599.05483883],
#         [ 2082938.86448969,   -49599.05828932],
#         ...,
#         [-6827737.30555925,   -64121.16318815],
#         [-6827737.30556773,   -64121.16585855],
#         [-6827737.30555941,   -64121.16324455]]),
#  array([[ 1.        ,  0.        ,  0.        , ..., 41.65263   ,
#          37.98448188, 30.32851097],
#         [ 0.        ,  1.        ,  0.        , ..., 41.65263   ,
#          37.98448188, 30.32851097],
#         [ 0.        ,  0.        ,  1.        , ..., 41.65263   ,
#          37.98448188, 90.        ],
#         ...,
#         [ 1.        ,  0.        ,  0.        , ...,  5.        ,
#          41.53784946,  4.5       ],
#         [ 0.        ,  1.        ,  0.        , ...,  0.        ,
#          41.53784946,  5.        ],
#         [ 0.        ,  0.        ,  1.        , ...,  4.5       ,
#          41.53784946,  4.5       ]]))

# %%
#returns C, ss, M, X, Ye given dimensions of reduced space
ppca_X[3]
# Out:
# array([[ 2082938.8644985 ,   -49599.05483887],
#        [ 2082938.86449851,   -49599.05483883],
#        [ 2082938.86448969,   -49599.05828932],
#        ...,
#        [-6827737.30555925,   -64121.16318815],
#        [-6827737.30556773,   -64121.16585855],
#        [-6827737.30555941,   -64121.16324455]])
